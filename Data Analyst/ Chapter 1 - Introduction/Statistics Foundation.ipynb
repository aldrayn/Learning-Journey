# %% [markdown]
# ### **Statistics**

# %% [markdown]
# #### **Foundation**

# %% [markdown]
# Karena:
#
# > Naik sedikit belum tentu benar-benar lebih baik.
#
# Bisa saja hanya kebetulan/random, oleh karena itu dibutuhkan analisis statistik.

# %% [markdown]
# **Konsep Dasar - Hipotesis**
#
#
# - Null Hypothesis $(H_0)$
#
#     Tidak ada perbedaan antara A dan B.
#
#     $$H_0​:μ_A​=μ_B​$$
#
# - Alternative Hypothesis $(H_1)$
#
#     Ada perbedaan antara A dan B.
#
#     $$H_1	​:μ_A \ne μ_B$$
#
#     Kadang juga:
#
#     $$H1	​:μ_B	​>μ_A$$
#
#     ​(jika ingin membuktikan versi baru lebih baik)

# %% [markdown]
# ##### **P-value**

# %% [markdown]
# > Mengukur probabilitas hasil terjadi secara kebetulan.
#
#
# Kalau:
#
# $
# p < 0.05
# $
#
# Artinya:
# * kemungkinan hasil terjadi karena kebetulan sangat kecil,
# * maka kita percaya treatment memang berbeda.
#
#
# Decision Rule
#
# - Jika:
#
#     $
#     p < 0.05
#     $
#
#     Maka:
#     - Tolak (H_0)
#     - Ada perbedaan signifikan.
# - Jika:
#
#     $
#     p \geq 0.05
#     $
#
#     Maka:
#     - Gagal menolak (H_0)
#     - Belum ada bukti cukup.

# %% [markdown]
# ##### **Standard Error (SE)**

# %% [markdown]
# > Mengukur seberapa stabil hasil sampel kita.
#
# SE membantu menjawab:
#
# > “Kalau eksperimen diulang terus, hasilnya bakal berubah banyak atau tidak?”
#
# Rumus:
#
# $$
# SE =
# \sqrt{
# \frac{p(1-p)}{n}
# }
# $$
#
# Keterangan:
# - $p$ : Proporsi/conversion rate sampel.
#
# Contoh:
# - Misalnya conversion rate:
#
#     5%
#
#     Kalau:
#
#     - user sedikit,
#     - data kecil,
#
#     maka hasil mudah berubah-ubah.
#
# - Hari ini:
#
#     5%
#
#     Besok:
#
#     8%
#
#     Lusa:
#
#     3%
#
#     Berarti SE besar.
#
# Interpretasi
# - Kalau user sangat banyak:
#
#     - hasil lebih konsisten,
#     - tidak gampang berubah.
#
#     Berarti SE kecil.
#
# - Kalau $n$ besar, SE kecil → hasil lebih terpercaya.
# - Kalau $n$ kecil, SE besar → hasil masih noisy/tidak stabil.

# %% [markdown]
# ##### **Confidence Interval (CI)**

# %% [markdown]
# > Memberikan range perkiraan nilai sebenarnya di populasi.
#
# Karena data yang kita ambil cuma sampel, kita tidak pernah benar-benar tahu nilai asli populasi.
# CI membantu menjawab:
#
# > “Kemungkinan nilai aslinya ada di sekitar mana?”
#
# Rumus
#
# $$
# CI =
# \bar{x}
# \pm
# Z \cdot \frac{\sigma}{\sqrt{n}}
# $$
# Keterangan:
# - $Z$ : Nilai dari distribusi normal $\to$ digunakan untuk menentukan tingkat keyakinan.
#
# Contoh
#
# - Misalnya conversion rate hasil eksperimen:
#
#     5%
#
#     > Tetapi itu belum tentu angka asli populasi.
#
# - Setelah dihitung CI:
#
#     5%±1%
#
#     Artinya:
#
#     kemungkinan besar nilai asli conversion rate ada di:
#
#     > 4% sampai 6%
#
# Interpretasi
# - CI itu seperti:
#
#     > “zona kemungkinan nilai asli.”
#
# - Semakin sempit CI:
#
#     - semakin yakin,
#     - estimasi makin stabil.

# %% [markdown]
# **Hubungan CI dan SE**
#
# > CI dibangun menggunakan SE.
#
# Karena:
#
# $$CI=\text{Estimasi}±(Z×SE)$$
#
# Artinya:
#
# - SE menentukan lebar CI.
# - Jika SE besar
#
#     - CI lebar
#     - ketidakpastian tinggi.
#
# - Jika SE kecil
#
#     - CI sempit
#     - estimasi lebih yakin/stabil.

# %% [markdown]
# ##### **Z-Score**

# %% [markdown]
# > Mengukur seberapa jauh perbedaan dari rata-rata.
#
# Rumus
# $$
# Z =
# \frac{\hat{p}_1 - \hat{p}_2}
# {SE}
# $$
# Keterangan:
# - $\hat{p}_1 \to$ Conversion rate group pertama.
# - $\hat{p}_2 \to$ Conversion rate group kedua.
#
# Intuisi:
#
# $$Z= \frac{\text{Perbedaan Asli}}{\text{Noise}}$$
#
# Z-score mencoba menjawab:
#
# > “Perbedaan conversion ini besar banget atau sebenarnya kecil dibanding variasi/noise data?”

# %% [markdown]
# #### **Effect Size**

# %% [markdown]
# Effect size mengukur:
#
# > seberapa besar pengaruh/perbedaan antar grup.
#
# P-value cuma menjawab:
#
# > “Apakah ada perbedaan?”
#
# Tapi effect size menjawab:
#
# > “Perbedaannya BESAR atau kecil?”
#
# Misalnya:
#
# | Group | Conversion |
# |-- |------- |
# | A     | 5.00%      |
# | B     | 5.01%      |
#
# Dengan user jutaan
#
# > perbedaan bisa signifikan.
#
# Tapi…
#
# > peningkatannya hampir tidak berguna secara bisnis.
#
# Nah effect size membantu melihat:
#
# > apakah efeknya meaningful.

# %% [markdown]
# **Cohen’s d**
#
# > Salah satu effect size paling populer.
#
# Rumus
#
# $$
# d=
# \frac{μ_1−μ_2}{σ}
# $$	​
#
# 	​
#
# Keterangan Variabel
# - $μ_1$ : Rata-rata grup pertama $\to$ Biasanya control/A.
#
# - $μ_2$ : Rata-rata grup kedua $\to$ Biasanya treatment/B.
#
# - σ : Standard deviation $\to$ Mengukur variasi data.
#
# Intuisi Formula
#
# $$d= \frac{\text{perbedaan}}{\text{variasi}}$$
# 	​
#
# Cohen’s d mencoba melihat:
#
# > “Perbedaannya besar dibanding noise data atau tidak?”
#
# Interpretasi Cohen’s d
#
# | Cohen’s d | Interpretasi |
# |------ |--------- |
# | 0.2       | efek kecil   |
# | 0.5       | efek sedang  |
# | 0.8       | efek besar   |
#
# Misalnya:
#
# | Group | Mean Revenue |
# |-- |--------- |
# | A     | 100          |
# | B     | 120          |
#
# Dengan standar deviasi $(σ)$ adalah 40, maka:
#
# $$d=\frac{120−100}{40}	​=0.5$$
#
# Artinya:
# > efek perubahan cukup sedang/moderat.

# %% [markdown]
# **P-value vs Effect Size**
#
# | P-value                          | Effect Size                    |
# |----------------------------- |--------------------------- |
# | Apakah signifikan?               | Seberapa besar efeknya?        |
# | Dipengaruhi sample size          | Fokus ke besar efek            |
# | Bisa signifikan walau efek kecil | Mengukur meaningful atau tidak |

# %% [markdown]
# #### **Hypotesis Test**

# %% [markdown]
# ##### **T-Test**

# %% [markdown]
# Dipakai jika
#
# * membandingkan rata-rata,
# * data numerik.
#
# Contoh:
#
# * rata-rata revenue,
# * waktu penggunaan,
# * rata-rata order value.
#
#
# Rumus
#
# $$
# t =
# \frac{
# \bar{x}_1 - \bar{x}_2
# }
# {
# SE
# }
# $$
#
#
# Keterangan
#
# * (\bar{x}_1) = rata-rata grup A
# * (\bar{x}_2) = rata-rata grup B
# * (SE) = standard error perbedaan
#
#
# T-Test mencoba melihat:
#
# > “Apakah perbedaan rata-rata ini cukup besar dibanding noise data?”

# %% [markdown]
# ##### **Chi-Squared Test**

# %% [markdown]
# Dipakai untuk
#
# * data kategori,
# * conversion yes/no,
# * click/no click.
#
#
# Rumus
#
# $$
# \chi^2 =
# \sum
# \frac{
# (O - E)^2
# }{E}
# $$
#
#
# Keterangan
#
# * (O) = observed value (data asli)
# * (E) = expected value (nilai harapan)
#
#
# Chi-square mencoba melihat:
#
# > “Apakah hasil kategori yang muncul berbeda jauh dari yang seharusnya?”
#
# Misalnya:
#
# * expected conversion = 50,
# * ternyata dapat 80.
#
# Test mengecek:
#
# > apakah selisih itu terlalu besar untuk dianggap kebetulan?

# %% [markdown]
# ##### **Z-Test**

# %% [markdown]
# Dipakai untuk
#
# * conversion rate besar,
# * proporsi,
# * sample besar.
#
#
# Rumus
#
# $$
# Z =
# \frac{
# \hat{p}_1 - \hat{p}_2
# }
# {SE}
# $$
#
#
# Keterangan
#
# * (\hat{p}_1) = conversion rate A
# * (\hat{p}_2) = conversion rate B
# * (SE) = standard error
#
#
# Intuisi
#
# Z-Test mencoba melihat:
#
# > “Apakah selisih conversion cukup besar dibanding variasi/noise?”

# %% [markdown]
# ##### **ANOVA**

# %% [markdown]
# Dipakai untuk
#
# > membandingkan lebih dari 2 grup.
#
#
# Contoh
#
# | Group |
# |-- |
# | A     |
# | B     |
# | C     |
#
# Misalnya:
#
# > 3 desain landing page.
#
#
# Rumus Dasar
#
# $$
# F =
# \frac{
# \text{Variasi antar grup}
# }
# {
# \text{Variasi dalam grup}
# }
# $$
#
# ANOVA mencoba melihat:
#
# > “Apakah perbedaan antar grup lebih besar dibanding variasi normal di dalam grup?”
#
#
# Kalau F besar, artinya:
#
# * kemungkinan ada grup yang berbeda signifikan.
#
#
# Tambahan:
# ANOVA hanya memberi tahu:
#
# > “Ada perbedaan.”
#
# Tapi belum memberi tahu:
#
# > grup mana yang berbeda.
#
# Biasanya lanjut:
#
# * Post-hoc test
# * Tukey test
# * pairwise comparison.

# %%
---

# Decision dalam AB Testing

---

# Case 1 — Treatment Lebih Baik & Signifikan

Contoh:

* CR naik
* p-value < 0.05

## Decision

✅ Gunakan versi B.

---

# Case 2 — Treatment Naik Tapi Tidak Signifikan

## Decision

❌ Belum cukup bukti.

Mungkin:

* sample kurang besar,
* efek terlalu kecil.

---

# Case 3 — Treatment Turun

## Decision

❌ Jangan deploy.

---

# Faktor Penting dalam AB Testing

---

# 1. Sample Size

Kalau terlalu sedikit:

* hasil tidak stabil,
* noisy.

---

# 2. Randomization

User harus dibagi secara acak.

---

# 3. Bias

Hindari:

* traffic tidak seimbang,
* waktu berbeda,
* device berbeda.

---

# 4. Peeking Problem

Jangan cek hasil terus-menerus lalu stop ketika menang.

Karena:

* bisa menghasilkan false positive.

---

# Flow AB Testing

1. Tentukan tujuan
2. Tentukan metrik
3. Buat hipotesis
4. Split user
5. Jalankan eksperimen
6. Hitung metrik
7. Uji statistik
8. Ambil keputusan

# %% [markdown]
# #### **Statistic Power**

# %% [markdown]
# Power mengukur:
#
# > “Seberapa besar kemungkinan eksperimen berhasil mendeteksi perbedaan nyata.”
#
# Kenapa efek kecil sulit dideteksi? karena di data nyata selalu ada:
#
# - noise,
# - variasi user,
# - randomness.
#
# Kalau perubahannya kecil banget:
#
# | Group | CR    |
# |-- |-- |
# | A     | 5.00% |
# | B     | 5.05% |
#
# Selisihnya cuma:
#
# > 0.05%
#
# Masalahnya noise data bisa lebih besar dari selisih itu. Misalnya:
# - hari ini conversion naik,
# - besok turun,
# - user behavior berubah,
# - traffic berbeda.
#
# Akhirnya:
# > sinyal efek kecil “tertutup” oleh noise.
#
# Maka untuk efek kecil biasanya perlu:
#
# - sample lebih besar
# - durasi eksperimen lebih lama
# - data lebih stabil
#
# Supaya:
#
# - noise relatif mengecil,
# - sinyal efek mulai terlihat.
#
# Umumnya target power adalah 80% karena dianggap kompromi yang bagus. Ini artinya adalah:
#
# > Kalau efek nyata memang ada 80% kemungkinan eksperimen berhasil menemukannya.

# %% [markdown]
# **Hubungan dengan Type II Error**
#
# Type II Error (β) terjadi ketika:
#
# > efek sebenarnya ada, tapi test bilang tidak ada.
#
# Rumus
#
# $$\text{Power}=1−β$$
#
# Contoh
#
# - Kalau:
#
#     $$β=0.2$$
#
# - Maka:
#
#     $$Power=0.8=80\%$$

# %% [markdown]
# Faktor yang Mempengaruhi Power
# - Sample Size
#
#     Semakin besar sample:
#
#     > power naik.
#
#     Karena:
#
#     - noise lebih kecil,
#     - hasil lebih stabil.
#
# - Effect Size
#
#     Semakin besar efek:
#     > semakin mudah dideteksi.
#
#     Misal:
#
#     > conversion naik dari 5% → 20% $\to$ mudah terlihat.
#
#     Tapi kalau:
#
#     > 5% → 5.2% $\to$ lebih sulit.
#
# - Noise / Variasi Data
#
#     > Semakin noisy data $\to$ semakin sulit mendeteksi efek.
#
# - Significance Level (α)
#
#     Biasanya:
#
#     0.05
#
#     Kalau threshold terlalu ketat:
#
#     > lebih sulit mendapatkan signifikan, power turun.

# %% [markdown]
# **Contoh Nyata**
#
# Misalnya:
#
# |Group	|CR|
# |-------|--|
# |A	    |5%|
# |B	    |6%|
#
# Kelihatannya naik, tapi:
#
# > user cuma 50.
#
# Akhirnya:
#
# - p-value besar,
# - tidak signifikan.
#
# Bukan berarti:
#
# > tombol baru jelek.
#
# Bisa jadi:
#
# > data belum cukup.
